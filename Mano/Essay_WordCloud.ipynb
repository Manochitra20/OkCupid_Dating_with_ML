# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import zipfile

# %%
zf = zipfile.ZipFile('../users_essay.zip') # having First.csv zipped file.
df = pd.read_csv(zf.open('users_essay.csv'))

# display dataset
df.head()
# Out:
#   Unnamed: 0                                             essay0  \
# 0          0  about me:<br />\n<br />\ni would love to think...
# 1          1  i am a chef: this is what that means.<br />\n1...
# 2          2  i'm not ashamed of much, but writing public te...
# 3          3          i work in a library and go to school. . .
# 4          4  hey how's it going? currently vague on the pro...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
# 3          reading things written by old dead people
# 4                         work work work work + play
#
#                                               essay2  \
# 0  making people laugh.<br />\nranting about a go...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
# ...

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

# Create stopword list:
# stopwords = set(stopwords)
stop_words = set(stopwords.words('english')) 
stop_words.update(["br", "href"])
textt = " ".join(review for review in df.essay6)
wordcloud = WordCloud(stopwords=stop_words).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud11.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ng/g2rw737s09b_hmsyrmqzpq300000gn/T/ipykernel_60904/887009496.py in <module>
#       7 stop_words = set(stopwords.words('english'))
#       8 stop_words.update(["br", "href"])
# ----> 9 textt = " ".join(review for review in df.essay6)
#      10 wordcloud = WordCloud(stopwords=stop_words).generate(textt)
#      11 plt.imshow(wordcloud, interpolation='bilinear')
#
# TypeError: sequence item 1: expected str instance, float found

# %%
import re
def remove_tags(string):
    result = re.sub('<.*?/\brn?+>','',string)
    return result
df['with_out_tags']=df['essay1'].apply(lambda cw : remove_tags(cw))

print(df)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /var/folders/ng/g2rw737s09b_hmsyrmqzpq300000gn/T/ipykernel_60904/319788351.py in <module>
#       3     result = re.sub('<.*?/\brn?+>','',string)
#       4     return result
# ----> 5 df['with_out_tags']=df['essay1'].apply(lambda cw : remove_tags(cw))
#       6
#       7 print(df)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
text = " ".join(i for i in df.essay0)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ng/g2rw737s09b_hmsyrmqzpq300000gn/T/ipykernel_60904/1904550335.py in <module>
# ----> 1 text = " ".join(i for i in df.essay0)
#       2 stopwords = set(STOPWORDS)
#       3 wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
#       4 plt.figure( figsize=(15,10))
#       5 plt.imshow(wordcloud, interpolation='bilinear')
#
# TypeError: sequence item 7: expected str instance, float found
