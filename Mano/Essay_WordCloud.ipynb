# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import zipfile

# %%
zf = zipfile.ZipFile('../users_essay.zip') # having First.csv zipped file.
df = pd.read_csv(zf.open('users_essay.csv'))

# display dataset
df.head()
# Out:
#   Unnamed: 0                                             essay0  \
# 0          0  about me:<br />\n<br />\ni would love to think...
# 1          1  i am a chef: this is what that means.<br />\n1...
# 2          2  i'm not ashamed of much, but writing public te...
# 3          3          i work in a library and go to school. . .
# 4          4  hey how's it going? currently vague on the pro...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
# 3          reading things written by old dead people
# 4                         work work work work + play
#
#                                               essay2  \
# 0  making people laugh.<br />\nranting about a go...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
# 3  playing synthesizers and organizing books acco...
# 4  creating imagery to look at:<br />\nhttp://bag...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
# 3                  socially awkward but i do my best
# 4            i smile a lot and my inquisitive nature
#
#                                               essay4  \
# 0  books:<br />\nabsurdistan, the republic, of mi...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
# 3  bataille, celine, beckett. . .<br />\nlynch, j...
# 4  music: bands, rappers, musicians<br />\nat the...
#
#                                               essay5  \
# 0  food.<br />\nwater.<br />\ncell phone.<br />\n...
# 1  delicious porkness in all of its glories.<br /...
# 2  movement<br />\nconversation<br />\ncreation<b...
# 3                                                NaN
# 4                                                NaN
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
# 3   cats and german philosophy
# 4                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay9
# 0  you want to be swept off your feet!<br />\nyou...
# 1                                                NaN
# 2  you are bright, open, intense, silly, ironic, ...
# 3                              you feel so inclined.
# 4                                                NaN

# %%
df1=df.drop(['Unnamed: 0'], axis = 1)

# %%
df1.isna().sum()
# Out:
# essay0    2577
# essay1    3646
# essay2    4559
# essay3    5471
# essay4    4948
# essay5    5201
# essay6    6479
# essay7    5960
# essay8    9035
# essay9    5862
# dtype: int64

# %%
df1_new = df1.dropna()

# %%
df1_new.shape
# Out:
# (13839, 10)

# %%
clean_df = df1_new.replace({r'<[A-Za-z\/][^>]*>' : '', r'\n' : ' ', r'http[^ ]*[ ]' : ' ', r'http[^ ]*' : ''}, regex=True)
clean_df.head()
# Out:
#                                                essay0  \
# 0   about me:  i would love to think that i was so...
# 5   i'm an australian living in san francisco, but...
# 9   my names jake. i'm a creative guy and i look f...
# 10  update: i'm seeing someone, so off the market ...
# 11  i was born in wisconsin, grew up in iowa, and ...
#
#                                                essay1  \
# 0   currently working as an international agent fo...
# 5   building awesome stuff. figuring out what's im...
# 9   i have an apartment. i like to explore and che...
# 10  i have three jobs. i've been doing sound and l...
# 11  i'm currently the youngest member on an intern...
#
#                                                essay2  \
# 0   making people laugh. ranting about a good salt...
# 5   imagining random shit. laughing at aforementio...
# 9   i'm good at finding creative solutions to prob...
# 10  hugging, kissing, laughing, motivating people,...
# 11  i'm really good at a little bit of everything....
#
#                                                essay3  \
# 0   the way i look. i am a six foot half asian, ha...
# 5   i have a big smile. i also get asked if i'm we...
# 9                                           i'm short
# 10                                my huge goofy smile
# 11  the way i dress. some days it's hats, other da...
#
#                                                essay4  \
# 0   books: absurdistan, the republic, of mice and ...
# 5   books: to kill a mockingbird, lord of the ring...
# 9   i like some tv. i love summer heights high and...
# 10  i'm constantly reading, i read at what my frie...
# 11  books = yes. avid reader. moves = eternal suns...
#
#                                                essay5  \
# 0                   food. water. cell phone. shelter.
# 5   like everyone else, i love my friends and fami...
# 9   music, my guitar contrast good food my bike my...
# 10            family friends food women music reading
# 11  guitar - even if i don't play it all the time,...
#
#                                                essay6  \
# 0                         duality and humorous things
# 5   what my contribution to the world is going to ...
# 9                                          you should
# 10  snowboarding, food, women, goofy nerd stuff, a...
# 11  a little bit of everything. but mostly social ...
#
#                                                essay7  \
# 0   trying to find someone to hang out with. i am ...
# 5                                out with my friends!
# 9                                      send a message
# 10  having dinner and drinks with friends and/or w...
# 11  hanging out with a small group of friends--sta...
#
#                                                essay8  \
# 0   i am new to california and looking for someone...
# 5   i cried on my first day at school because a bi...
# 9                                         and say hi.
# 10  i used to wish for a jetpack when blowing out ...
# 11  i'm picky when it comes to dating. i know what...
#
#                                                essay9
# 0   you want to be swept off your feet! you are ti...
# 5                                     you're awesome.
# 9                              you can rock the bells
# 10  you are a complex woman with healthy self-este...
# 11  if you know who you are, who you want, where y...

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd


text = " ".join(i for i in clean_df.essay0)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
essay_columns = ['essay0', 'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7', 'essay8', 'essay9']
clean_df['combined_essay'] = clean_df[essay_columns].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
clean_df
# Out:
#                                                   essay0  \
# 0      about me:  i would love to think that i was so...
# 5      i'm an australian living in san francisco, but...
# 9      my names jake. i'm a creative guy and i look f...
# 10     update: i'm seeing someone, so off the market ...
# 11     i was born in wisconsin, grew up in iowa, and ...
# ...                                                  ...
# 27742  -grew up in west hollywood, went to artsy priv...
# 27743  spent most of my early life in nj but have bee...
# 27744  i teach, travel, perform and tell stories. hum...
# 27745  i love to laugh and have fun. my family and fr...
# 27746  interested in getting a little weird, going to...
#
#                                                   essay1  \
# 0      currently working as an international agent fo...
# 5      building awesome stuff. figuring out what's im...
# 9      i have an apartment. i like to explore and che...
# 10     i have three jobs. i've been doing sound and l...
# 11     i'm currently the youngest member on an intern...
# ...                                                  ...
# 27742                           fighting with computers.
# 27743                  scheming up new adventures daily!
# 27744  storytelling, circus, clowning, mime, teaching...
# 27745  i'm completed my master's in sport management ...
# 27746  i have one more year left of law school. after...
#
#                                                   essay2  \
# 0      making people laugh. ranting about a good salt...
# 5      imagining random shit. laughing at aforementio...
# 9      i'm good at finding creative solutions to prob...
# 10     hugging, kissing, laughing, motivating people,...
# 11     i'm really good at a little bit of everything....
# ...                                                  ...
# 27742  -finding waldo  -applying saran wrap to contai...
# 27743  making crepes, ignoring my alarm clock, and go...
# 27744  adaptation - life's always changing, so you'd ...
# 27745             making people laugh. or so i'm told...
# 27746  roasting chickens, writing melodies, going to ...
#
#                                                   essay3  \
# 0      the way i look. i am a six foot half asian, ha...
# 5      i have a big smile. i also get asked if i'm we...
# 9                                              i'm short
# 10                                   my huge goofy smile
# 11     the way i dress. some days it's hats, other da...
# ...                                                  ...
# 27742                                  my heart of gold.
# 27743  that i'm oblivious to people noticing me... an...
# 27744  i love serious conversations, debates, quiet l...
# 27745   hm, maybe my small eyes or my 'contagious laugh'
# 27746             that i look a lot like president obama
#
#                                                   essay4  \
# 0      books: absurdistan, the republic, of mice and ...
# 5      books: to kill a mockingbird, lord of the ring...
# 9      i like some tv. i love summer heights high and...
# 10     i'm constantly reading, i read at what my frie...
# 11     books = yes. avid reader. moves = eternal suns...
# ...                                                  ...
# 27742  a: the secret history / donna tartt boys life ...
# 27743  books: a million little pieces, blink, tipping...
# 27744  this was the hardest section to trim down, so ...
# 27745  just a few favorites;  movies: wall street, an...
# 27746  books: tender is the night, sometimes a great ...
#
#                                                   essay5  \
# 0                      food. water. cell phone. shelter.
# 5      like everyone else, i love my friends and fami...
# 9      music, my guitar contrast good food my bike my...
# 10               family friends food women music reading
# 11     guitar - even if i don't play it all the time,...
# ...                                                  ...
# 27742  -sectionals and conversation pits  -anything s...
# 27743  1. a sunny warm day 2. music 3. fresh bread 4....
# 27744  time and energy to create. great food. regular...
# 27745  friends family espn iphone sun my extra large ...
# 27746  guitar, stove, pen and paper, books, sports, l...
#
#                                                   essay6  \
# 0                            duality and humorous things
# 5      what my contribution to the world is going to ...
# 9                                             you should
# 10     snowboarding, food, women, goofy nerd stuff, a...
# 11     a little bit of everything. but mostly social ...
# ...                                                  ...
# 27742  things to add to my to do list  what i wanna e...
# 27743  all the awesome places in the world i still wa...
# 27744  teaching. lesson planning. the performing arts...
# 27745  my future, places of the world i want to see, ...
# 27746  living the dream, criminal law, new instrument...
#
#                                                   essay7  \
# 0      trying to find someone to hang out with. i am ...
# 5                                   out with my friends!
# 9                                         send a message
# 10     having dinner and drinks with friends and/or w...
# 11     hanging out with a small group of friends--sta...
# ...                                                  ...
# 27742  shouting over really loud music at a bar with ...
# 27743  a. beat up from work and enjoying some wine or...
# 27744  i have mellow fridays. if i'm not at a theatre...
# 27745  spending time with friends, going out for dinn...
# 27746  going to happy hour, then dinner. come home sh...
#
#                                                   essay8  \
# 0      i am new to california and looking for someone...
# 5      i cried on my first day at school because a bi...
# 9                                            and say hi.
# 10     i used to wish for a jetpack when blowing out ...
# 11     i'm picky when it comes to dating. i know what...
# ...                                                  ...
# 27742  i take the "three second rule" to unhealthy ex...
# 27743  i'm a big fan of costume parties and although ...
# 27744  i'm a total workaholic... but it's hard not to...
# 27745                     take me out and i'll tell you.
# 27746  most of my friends are in serious relationship...
#
#                                                   essay9  \
# 0      you want to be swept off your feet! you are ti...
# 5                                        you're awesome.
# 9                                 you can rock the bells
# 10     you are a complex woman with healthy self-este...
# 11     if you know who you are, who you want, where y...
# ...                                                  ...
# 27742  you think we could make beautiful music together.
# 27743  you like brunettes and if you enjoy the outdoo...
# 27744  ask me questions! tell me answers! write absol...
# 27745  you love to laugh, enjoy sports, and are down ...
# 27746  when you pass someone on the street you smile ...
#
#                                           combined_essay
# 0      about me:  i would love to think that i was so...
# 5      i'm an australian living in san francisco, but...
# 9      my names jake. i'm a creative guy and i look f...
# 10     update: i'm seeing someone, so off the market ...
# 11     i was born in wisconsin, grew up in iowa, and ...
# ...                                                  ...
# 27742  -grew up in west hollywood, went to artsy priv...
# 27743  spent most of my early life in nj but have bee...
# 27744  i teach, travel, perform and tell stories. hum...
# 27745  i love to laugh and have fun. my family and fr...
# 27746  interested in getting a little weird, going to...
#
# [13839 rows x 11 columns]

# %%
text = " ".join(i for i in clean_df.combined_essay)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from PIL import Image
# Generate a word cloud image
stopwords = set(STOPWORDS)
mask = np.array(Image.open("Input_img/heart.png"))
wordcloud = WordCloud(stopwords=stopwords, 
                      background_color="white", 
                      max_words=1000, mask=mask).generate(' '.join(clean_df['combined_essay']))
# create twitter image
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# store to file
#plt.savefig("twitter.png", format="png")
plt.show()

# %%
from PIL import Image
font = 'Fonts/Quicksand-Bold.ttf'

custom_mask = np.array(Image.open("Input_img/heart.png"))
stopwords = set(STOPWORDS)
wordcloud = WordCloud( stopwords=stopwords,
                       mask=custom_mask,
                       width=1600,
                       height=800,
                       colormap='PuRd',
                       margin=0,
                       max_words=500,
                       max_font_size=300, min_font_size=30, 
                       background_color="white").generate(' '.join(clean_df['combined_essay']))

image_colors = ImageColorGenerator(custom_mask)
wordcloud.recolor(color_func=image_colors)

plt.figure(figsize=(20, 20))
plt.imshow(wordcloud, interpolation="gaussian")
plt.axis("off")
plt.savefig("word_cloud.png", format="png")
plt.show()
