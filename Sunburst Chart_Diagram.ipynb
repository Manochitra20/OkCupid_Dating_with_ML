# %%
import pandas as pd
import numpy as np

pd.set_option("max_columns", 30)

import plotly.express as px
import plotly.graph_objects as go

# %%
OKCupid_locations = pd.read_csv("OKcupid_cleaned_up.csv")
OKCupid_locations.head()
# Out:
# C:\Users\sarma\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0  age body_type                diet  drinks               drugs  \
# 0           0   22     curvy            anything  rarely               never
# 1           1   35   average            anything  rarely           sometimes
# 2           2   38    skinny            anything  rarely  declined to answer
# 3           3   23    skinny          vegetarian  rarely  declined to answer
# 4           4   29  athletic  declined to answer  rarely               never
#
#             education            ethnicity height  income  \
# 0  declined to answer         asian, white   75.0   29592
# 1  college/university                white   70.0   48630
# 2     masters program   declined to answer   68.0   60812
# ...

# %%
OKCupid_locations.rename( columns={'Unnamed: 0': 'Okcupid'}, inplace=True )
OKCupid_locations.head()
# Out:
#    Okcupid  age body_type                diet  drinks               drugs  \
# 0        0   22     curvy            anything  rarely               never
# 1        1   35   average            anything  rarely           sometimes
# 2        2   38    skinny            anything  rarely  declined to answer
# 3        3   23    skinny          vegetarian  rarely  declined to answer
# 4        4   29  athletic  declined to answer  rarely               never
#
#             education            ethnicity height  income  \
# 0  declined to answer         asian, white   75.0   29592
# 1  college/university                white   70.0   48630
# 2     masters program   declined to answer   68.0   60812
# 3  declined to answer                white   71.0   18578
# 4  college/university  asian, black, other   66.0   94691
#
#                            job       last_online  \
# 0               transportation  2012-06-28-20-30
# 1         hospitality / travel  2012-06-29-21-41
# ...

# %% [markdown]
# # Plotly Express

# %%
OKCupid_dist = OKCupid_locations.groupby(by=["location", "body_type", "job"]).count()
OKCupid_dist ['Okcupid'] = "Okcupid"
OKCupid_dist = OKCupid_dist .reset_index()
OKCupid_dist.head()
# Out:
#               location body_type                                job  Okcupid  \
# 0  alameda, california  athletic        artistic / musical / writer  Okcupid
# 1  alameda, california  athletic  banking / financial / real estate  Okcupid
# 2  alameda, california  athletic     computer / hardware / software  Okcupid
# 3  alameda, california  athletic       construction / craftsmanship  Okcupid
# 4  alameda, california  athletic                 declined to answer  Okcupid
#
#    age  diet  drinks  drugs  education  ethnicity  height  income  \
# 0    7     7       7      7          7          7       7       7
# 1    3     3       3      3          3          3       3       3
# 2   11    11      11     11         11         11      11      11
# 3    4     4       4      4          4          4       4       4
# 4   47    47      47     47         47         47      47      47
#
#    last_online  offspring  orientation  pets  religion  sex  sign  smokes  \
# ...

# %%
fig = px.sunburst(OKCupid_dist,
                  path=["Okcupid", "location", "body_type", "job"],
                  values='Count',
                  title="Okcupid App[location, body_type, job]",
                  width=750, height=750)
fig.show()
# Out:
#   File "C:\Users\sarma\AppData\Local\Temp/ipykernel_12540/2700568993.py", line 2
#     path=[location', 'body_type', 'job', 'Okcupid', 'age', 'diet', 'drinks', 'drugs', 'education', 'ethnicity', 'height', 'income', 'last_online', 'offspring', 'orientation', 'pets', 'religion', 'sex', 'sign', 'smokes', 'speaks', 'status', 'religion_cleaned', 'sign_cleaned'],
#                   ^
# SyntaxError: invalid syntax

# %%
ig = px.sunburst(starbucks_dist,
                  path=["Okcupid",  "location", "body_type", "job""],
                  values='Count',
                  title="Starbucks Store Count Distribution World Wide [Country, State, City]",
                  width=750, height=750)
fig.show()
# Out:
#   File "C:\Users\sarma\AppData\Local\Temp/ipykernel_12540/2993460560.py", line 2
#     path=["Okcupid",  "location", "body_type", "job""],
#                                                        ^
# SyntaxError: EOL while scanning string literal
